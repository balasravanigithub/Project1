# %% [markdown]
# <a href="https://colab.research.google.com/github/balasravanigithub/Project1/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install docx2txt
import docx2txt
import cv2
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3960 sha256=1fab0041fe8d03119b9c9778c4c6fbd2b8d6f1526712457d5b491d9c820e3a30
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
# Successfully built docx2txt
# ...

# %%
resume=docx2txt.process("/Bala Sravani Resume1.docx")
print(resume)
resume1=docx2txt.process("/NAVYA1 . RESUME.docx")

resume2=docx2txt.process("/Prasanth.docx")
# Out:
# BALA SRAVANI PEDAKOTLA
#
#   Email : balasravani2244@gmail.com                                   Mobile No : +91- 9912520861
#
#   CAREER OBJECTIVE
#
# To obtain a challenging career in the IT Industry and put all my efforts into the growth of the organization and have a great working environment that effectively utilizes any analytical, leadership , interpersonal or organizational skills to conceive and achieve solutions. The solutions which help the organization is not only meeting it’s target but also allowing it to grow, thereby enhancing my own skills as an individual and as a key player in the organization’s development.
#
#   EDUCATIONAL QUALIFICATIONS
#
#   Master of Computer Applications                                                                          2022-2024
#
#   Vignan’s Lara Institute of Technology and Sciences, Vadlamudi.                          CGPA – 8.1
#
# ...

# %%
l=[resume,resume1,resume2]
for i in l:
    print(i,end="\n")
# Out:
# BALA SRAVANI PEDAKOTLA
#
#   Email : balasravani2244@gmail.com                                   Mobile No : +91- 9912520861
#
#   CAREER OBJECTIVE
#
# To obtain a challenging career in the IT Industry and put all my efforts into the growth of the organization and have a great working environment that effectively utilizes any analytical, leadership , interpersonal or organizational skills to conceive and achieve solutions. The solutions which help the organization is not only meeting it’s target but also allowing it to grow, thereby enhancing my own skills as an individual and as a key player in the organization’s development.
#
#   EDUCATIONAL QUALIFICATIONS
#
#   Master of Computer Applications                                                                          2022-2024
#
#   Vignan’s Lara Institute of Technology and Sciences, Vadlamudi.                          CGPA – 8.1
#
# ...

# %%
print("Extracting data from the resume")
enter=input("Enter user input")
if enter=='technical':
  print(docx2txt.process("/1.docx"))
elif enter=="project":
  print(docx2txt.process("/2.docx"))
elif enter=="details":
  print(docx2txt.process("/3.docx"))
else:
  pass
# Out:
# Extracting data from the resume
# Enter user inputtechnical
# TECHNICAL SKILLS
#
# C
#
# Core Java
#
# Python
#
# Web Development – HTML, CSS, JavaScript.
#
#
#
#
# $qƒ²ì¤íK—íþÿ_·ƒl§Iê4ÎÕæeõ9VÁ ‘fX°`Á‚¯…uñßÃú
# dG_œó¿Cµïh
# ¼(:ùá.ì¥Ÿl1˜«‚“Ã¨yé
#
# Ø/<—®Â„íà^¾K¡¿yé
#
# ÈëóÀªù_5	¼8ý?ÁÃ«ãóP½<ÉSy—ß./ž@_oãäã§üT^ÂUò›è.»'Pº'ñ`ŠÍöbº:ónx,}ùM\tÅù%ŸÒ9Èi¼h·5ã‰¥Y}÷=ÂSxPWgWç¿þöñêêì1
#  ‚'¼ï9Ô@
#
# 5£§•e›ËOgŸ¾}›Åñ|§ð0þóé¾œ}ùryvþé»|ÏÁf[ÍW-†m¡ñ?ßo'µ¥âãÙÇË³‹—._\Aý›+”ž«UÆW7óøƒ8‰‡øãüãÙ§ÿùøùìêå¯ô~l\\}íjeky¾ú÷y<èï_¿^^~ùñåó=-òu°qÓjEV+1_×*<‹¸ºüðããWü¼¸1õ;lœøèÌê ¯IZ]<ê¿É­“{ñëü6Î­v—·Y]ÐÏÛçñ@†sç·ß¤zÙ‹|› V«Ü!a{Šãjõ<êñËÄ¯®ÒŸì•æ~i³Z]e©À«äÕ³x ÿž}ýl?~½ø^þJïòãÜ±î­œá<|¼üqùéËÙ·/ß¿Ÿ&Ô"zUÄG¿i`°“q®ˆ“Šì	Íà“cTxú~lçKÖ.ö¦žÎCùÕÙoŸ¾ýöm¸GSþZ=¿À…ÿì‘|Á/¡˜~À—¶¸L
#
# -%8o'Öwk¿y19ç¬µn‡íEûdàã×O.ÏÎ¶ß¾¬N´Ìýxñ
# Øì&6ç+Ðü
# |€Ø¹!ŸfÜlÀK¥±á&Ò=à4™^ýˆøüõÛi ì
# +ìV*çÀlòˆŸ9
# 4sÚ³q
#
# ¤ÔCkCåŸÕ§áúífÜ\
# ~6ŸþÌe=
#
# ‹?}wÝ-ö3½Úvèáæ‰gàEy¨>ûËæ_~îÎDqîÜGY ­¾Þ~H#ÿG0é_ÿé>ØÑ~†
# éœCí¾{û¿rz/û>ÛsXÁ§â’À
#
# ...
